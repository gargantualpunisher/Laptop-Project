# %%
import pickle
import seaborn as sns 
import matplotlib.pyplot as plt 
# %matplotlib inline
import pandas as pd

# %%
data = pd.read_excel(r"D:\database\LAPTOP DATASET1.xlsx")

# %%
data
# Out:
#       IPS  Touchscreen Company            TypeName  Inches  Ram  \
# 0       1            0   Apple           Ultrabook    13.3    8
# 1       0            0   Apple           Ultrabook    13.3    8
# 2       0            0      HP            Notebook    15.6    8
# 3       1            0   Apple           Ultrabook    15.4   16
# 4       1            0   Apple           Ultrabook    13.3    8
# ...   ...          ...     ...                 ...     ...  ...
# 1262    1            1  Lenovo  2 in 1 Convertible    14.0    4
# 1263    1            1  Lenovo  2 in 1 Convertible    13.3   16
# 1264    0            0  Lenovo            Notebook    14.0    2
# 1265    0            0      HP            Notebook    15.6    6
# 1266    0            0    Asus            Notebook    15.6    4
#
#      graphic_processor     GPU  gigah       OpSys  Weight        Price  \
# 0                Intel    Iris    2.3       macOS    1.37   71378.6832
# ...

# %% [markdown]
# # Explanatroy Data Analysis

# %% [markdown]
# # Top 10 Expensive laptops

# %%
top_10 = data[data['Price'] > 180000]

# %%
sns.barplot(data=top_10, y='Price', x='Company', hue='Price')
# Out:
# <Axes: xlabel='Company', ylabel='Price'>

# %% [raw]
# # in top 10 expensive laptops, razer is high priced as comapred to other laptops which is more than 2,50,000
# # in top 10 laptops include Razer, Asus, Lenovo, Dell and HP

# %% [markdown]
# # Touchscreen

# %%
data['Touchscreen'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
pivot_table_data = data.pivot_table(index='Company', columns='Touchscreen', values='Price')
pivot_table_data.plot(kind='bar')
# Out:
# <Axes: xlabel='Company'>

# %% [raw]
# # Touch screen laptop with touchscreen are sold at high price as compared to non touchscreen laptops

# %% [markdown]
# # Company vs TypeName

# %%
pd.crosstab(data['Company'], data['TypeName'])
# Out:
# TypeName   2 in 1 Convertible  Gaming  Netbook  Notebook  Ultrabook  \
# Company
# Acer                        8       8        5        77          4
# Apple                       0       0        0         0         21
# Asus                       13      53        3        66         20
# Chuwi                       0       0        0         3          0
# Dell                       28      40        2       158         47
# Fujitsu                     0       0        0         2          0
# Google                      0       0        0         0          3
# HP                         18      12        9       179         34
# Huawei                      0       0        0         0          2
# LG                          0       0        0         0          3
# Lenovo                     46      32        4       173         30
# MSI                         0      53        0         0          0
# Mediacom                    1       0        0         6          0
# ...

# %%
pd.crosstab(data['Company'], data['TypeName']).plot()
# Out:
# <Axes: xlabel='Company'>

# %% [markdown]
# # primary_memory_1 vs TypeName

# %%
plt.figure(figsize=(8,7))
sns.barplot(data=data, x='TypeName', y='primary_memory_1')
plt.yticks([128, 500, 180, 240])
plt.show()

# %%
#

# %% [markdown]
# # IPS vs Company vs Price

# %%
data.pivot_table(index='Company', columns='IPS', values='Price')
# Out:
# IPS                    0              1
# Company
# Acer        27292.807236   45575.712000
# Apple       54490.947840   92355.984900
# Asus        53589.133077   83023.560000
# Chuwi       13157.229600   23922.720000
# Dell        57616.426175   94157.348400
# Fujitsu     38574.720000            NaN
# Google      89386.080000            NaN
# HP          53759.371018   70469.009542
# Huawei               NaN   75870.720000
# LG                   NaN  111834.720000
# Lenovo      40721.741690   77164.628661
# MSI         90993.448800   97210.349486
# Mediacom    13000.320000   16804.512000
# Microsoft   85903.788000            NaN
# Razer      192021.120000   95850.720000
# Samsung     89634.720000   35111.520000
# Toshiba     65379.888000   69160.574118
# Vero        10828.272000   13852.800000
# Xiaomi               NaN   60390.882000

# %% [markdown]
# # Company vs  Price

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x='Company', y='Price', data=data)
plt.title('Price by Company')
plt.xticks(rotation=45)
plt.show()

# %% [raw]
# # Razer company selling its laptops at high price then after this Lenovo and HP laptops are being sold less than Razer

# %% [markdown]
# # Inches

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data['Inches'], kde=True)
plt.title('Distribution of Inches')
plt.show()

# %%
 plt.figure(figsize=(10, 6))
sns.barplot(data=data, x='Inches', y='Price')
# Out:
# <Axes: xlabel='Inches', ylabel='Price'>

# %% [raw]
# # laptop screen size 15, 18.4 and 27.3 inches screen size is adopted for high price laptops highly
# # Inches is right skwed

# %% [markdown]
# # ram vs Price

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Ram', y='Price', data=data)
plt.title('Ram vs Price')
plt.show()

# %% [raw]
# # there is sort of linear relationship between ram and price, at some point with increase in price ram is increasing too, at some point

# %% [markdown]
# # Company vs primary_memory_1

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Company', y='primary_memory_1', data=data)
plt.title('Price by Company')
plt.xticks(rotation=45)
plt.show()

# %% [raw]
# # most of laptops got internal memory between 250 to 500,
# # acer, Dell, Lenovo and Razer offering more than 500 of internal memeory

# %% [markdown]
# # primary_memory_type

# %%
data['primary_memory_type'] = data['primary_memory_type'].str.strip()

# %%
data['primary_memory_type'].value_counts()
# Out:
# SSD              819
# HDD              366
# Flash Storage     72
# Hybrid            10
# Name: primary_memory_type, dtype: int64

# %%
data['primary_memory_type'].value_counts().plot(kind='barh')
# Out:
# <Axes: >

# %% [markdown]
# # Company vs Touchscreen

# %%
pd.crosstab(data['Company'], data['Touchscreen']).plot(kind='bar')
# Out:
# <Axes: xlabel='Company'>

# %% [markdown]
# # graphic_processor vs Price

# %%
plt.bar(data['graphic_processor'], data['Price'])
# Out:
# <BarContainer object of 1267 artists>

# %% [raw]
# # nvidia is being used in most expensive and gaming lapotops for high performance of laptops

# %% [markdown]
# # graphic_processor vs GPU

# %%
plt.scatter(data['graphic_processor'], data['GPU'])

# %% [markdown]
# # TypeName vs Price

# %%
sns.barplot(data=data, x='TypeName', y='Price')
# Out:
# <Axes: xlabel='TypeName', ylabel='Price'>

# %% [raw]
# # on average workstation laptops are high price laptops

# %%
sns.barplot(data=data, x='TypeName', y='Price', estimator='max')
# Out:
# <Axes: xlabel='TypeName', ylabel='Price'>

# %% [raw]
# # but when it comes to high price then gaming laptops are being sold at high price

# %% [markdown]
# # Distribution of data

# %% [markdown]
# # Inches

# %%
sns.histplot(data['Inches'])
# Out:
# <Axes: xlabel='Inches', ylabel='Count'>

# %% [raw]
# # it is right skewed, high number of data points between 11 to 16 and very lowest data points exceeding 17

# %% [markdown]
# # Ram

# %%
sns.histplot(data['Ram'])
# Out:
# <Axes: xlabel='Ram', ylabel='Count'>

# %% [raw]
# # as per above graph, most of data points lies between 4 to 16, 2 or more exceeding 20

# %% [markdown]
# # primary_memory_1

# %%
sns.histplot(data['primary_memory_1'])
# Out:
# <Axes: xlabel='primary_memory_1', ylabel='Count'>

# %% [markdown]
# # Weight

# %%
sns.histplot(data['Weight'])
# Out:
# <Axes: xlabel='Weight', ylabel='Count'>

# %% [raw]
# # most of latops weights lies between 1 to 3, there are only few laptops comes with high weight like gaming laptops

# %% [markdown]
# # OpSys vs Price

# %%
plt.figure(figsize=(11,8))
sns.barplot(data=data, x='OpSys', y='Price', estimator='max')
# Out:
# <Axes: xlabel='OpSys', ylabel='Price'>

# %% [raw]
# # most of expesive laptops comes with window 10

# %% [markdown]
# # CPU

# %%
data['CPU'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %% [raw]
# # intel processor is used in most of laptops
# # in gaming laptops AMD processor is used for high performance

# %% [markdown]
# # screen_varity

# %%
data['screen_varity'] = data['screen_varity'].str.strip()

# %%
data['screen_varity'].value_counts()
# Out:
# Full HD           841
# HD                299
# Quad HD+           47
# 4K Ultra HD        41
# Retina Display     17
# UHD                 9
# QHD                 8
# HD+                 3
# Quad HD             2
# Name: screen_varity, dtype: int64

# %%
data['screen_varity'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# # final Report

# %% [raw]
# # in top 10 expensive laptops, razer is high priced as comapred to other laptops which is more than 2,50,000
# # in top 10 laptops include Razer, Asus, Lenovo, Dell and HP
#
# # Touch screen laptop with touchscreen are sold at high price as compared to non touchscreen laptops
#
# # Razer company selling its laptops at high price then after this Lenovo and HP laptops are being sold less than Razer
#
# # nvidia is being used in most expensive and gaming lapotops for high performance of laptops
#
# # most of laptops got internal memory between 250 to 500,
# # acer, Dell, Lenovo and Razer offering more than 500 of internal memeory
#
# # on average workstation laptops are high price laptops
#
# # most of expesive laptops comes with window 10
#
# # as per above graph, most of data points lies between 4 to 16, 2 or more exceeding 20
#
# # it is right skewed, high number of data points between 11 to 16 and very lowest data points exceeding 17

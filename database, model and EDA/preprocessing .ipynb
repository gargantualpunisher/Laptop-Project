# %%
import pandas as pd
import numpy as np

# %%
file = pd.read_csv(r"D:\database\laptops\laptop data.csv")

# %%
file
# Out:
#       Unnamed: 0 Company            TypeName Inches  \
# 0              0   Apple           Ultrabook   13.3
# 1              1   Apple           Ultrabook   13.3
# 2              2      HP            Notebook   15.6
# 3              3   Apple           Ultrabook   15.4
# 4              4   Apple           Ultrabook   13.3
# ...          ...     ...                 ...    ...
# 1268        1298  Lenovo  2 in 1 Convertible     14
# 1269        1299  Lenovo  2 in 1 Convertible   13.3
# 1270        1300  Lenovo            Notebook     14
# 1271        1301      HP            Notebook   15.6
# 1272        1302    Asus            Notebook   15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...

# %% [markdown]
# # Data preprocessing

# %%
file['ScreenResolution']
# Out:
# 0               IPS Panel Retina Display 2560x1600
# 1                                         1440x900
# 2                                Full HD 1920x1080
# 3               IPS Panel Retina Display 2880x1800
# 4               IPS Panel Retina Display 2560x1600
#                            ...
# 1268     IPS Panel Full HD / Touchscreen 1920x1080
# 1269    IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1270                                      1366x768
# 1271                                      1366x768
# 1272                                      1366x768
# Name: ScreenResolution, Length: 1273, dtype: object

# %%
ips = []

# %%
for i in file['ScreenResolution']:
    if 'IPS' in i:
        ips.append(1)
    else:
        ips.append(0)

# %%
file['IPS'] = ips

# %%
file['IPS'].value_counts()
# Out:
# 0    914
# 1    359
# Name: IPS, dtype: int64

# %%
touch = []

# %%
for i in file['ScreenResolution']:
    if 'Touchscreen' in i:
        touch.append(1)
    else:
        touch.append(0)

# %%
file['Touchscreen'] = touch

# %%
file['Touchscreen'].value_counts()
# Out:
# 0    1088
# 1     185
# Name: Touchscreen, dtype: int64

# %%
file
# Out:
#       Unnamed: 0 Company            TypeName Inches  \
# 0              0   Apple           Ultrabook   13.3
# 1              1   Apple           Ultrabook   13.3
# 2              2      HP            Notebook   15.6
# 3              3   Apple           Ultrabook   15.4
# 4              4   Apple           Ultrabook   13.3
# ...          ...     ...                 ...    ...
# 1268        1298  Lenovo  2 in 1 Convertible     14
# 1269        1299  Lenovo  2 in 1 Convertible   13.3
# 1270        1300  Lenovo            Notebook     14
# 1271        1301      HP            Notebook   15.6
# 1272        1302    Asus            Notebook   15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...

# %% [markdown]
# # graphic

# %%
file['Graphic_chip'] = file['Gpu'].str.split().str.get(0)+' '+file['Gpu'].str.split().str.get(1)+' '+file['Gpu'].str.split().str.get(2)

# %%
file['Graphic_chip'].value_counts()
# Out:
# Intel HD Graphics         622
# Nvidia GeForce GTX        231
# Intel UHD Graphics         66
# AMD Radeon R5              53
# Nvidia GeForce 940MX       42
# AMD Radeon 530             39
# AMD Radeon R7              26
# Nvidia GeForce 930MX       25
# Nvidia GeForce 920MX       17
# AMD Radeon 520             16
# Nvidia GeForce MX150       15
# AMD Radeon RX              12
# Intel Iris Plus            10
# AMD Radeon R2               9
# Nvidia Quadro M1200         9
# AMD Radeon R4               8
# Nvidia GeForce 920M         6
# Nvidia GeForce MX130        6
# Nvidia GeForce GT           5
# Nvidia Quadro M620          5
# Nvidia GeForce 930M         5
# Nvidia Quadro M1000M        4
# Intel Iris Graphics         3
# AMD FirePro W4190M          3
# Nvidia GeForce 150MX        3
# Nvidia Quadro M2200M        3
# AMD Radeon Pro              3
# Nvidia Quadro M2200         2
# Nvidia Quadro M2000M        2
# Nvidia Quadro M520M         2
# AMD Radeon R9               1
# ...

# %% [markdown]
# # chip

# %%
chip = file['Cpu'].str.split().str.get(0)

# %%
file['gigah'] = file['Cpu'].str.split().str.get(-1)

# %%
file
# Out:
#       Unnamed: 0 Company            TypeName Inches  \
# 0              0   Apple           Ultrabook   13.3
# 1              1   Apple           Ultrabook   13.3
# 2              2      HP            Notebook   15.6
# 3              3   Apple           Ultrabook   15.4
# 4              4   Apple           Ultrabook   13.3
# ...          ...     ...                 ...    ...
# 1268        1298  Lenovo  2 in 1 Convertible     14
# 1269        1299  Lenovo  2 in 1 Convertible   13.3
# 1270        1300  Lenovo            Notebook     14
# 1271        1301      HP            Notebook   15.6
# 1272        1302    Asus            Notebook   15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...

# %%
mix  = file['Cpu'].str.split().str.get(0)+' '+ file['Cpu'].str.split().str.get(1)+' '+ file['Cpu'].str.split().str.get(2)

# %%
file['processor'] = mix

# %%
file
# Out:
#       Unnamed: 0 Company            TypeName Inches  \
# 0              0   Apple           Ultrabook   13.3
# 1              1   Apple           Ultrabook   13.3
# 2              2      HP            Notebook   15.6
# 3              3   Apple           Ultrabook   15.4
# 4              4   Apple           Ultrabook   13.3
# ...          ...     ...                 ...    ...
# 1268        1298  Lenovo  2 in 1 Convertible     14
# 1269        1299  Lenovo  2 in 1 Convertible   13.3
# 1270        1300  Lenovo            Notebook     14
# 1271        1301      HP            Notebook   15.6
# 1272        1302    Asus            Notebook   15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...

# %%
file.to_csv('output.csv', index=False)
